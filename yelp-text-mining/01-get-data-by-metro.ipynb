# %% [markdown]
# # Get Data by Metro Area

# %% [markdown]
# ## Load Packages

# %%
# Import packages to use later
import pandas as pd
import nltk
import time
import json

# %% [markdown]
# ## Investigate Cities

# %%
businesses = pd.read_csv("yelp_academic_dataset_business.csv")
businesses = businesses.rename(columns={'business': 'business_id'})

d = dict(businesses['metroarea'].value_counts())

for city, count in sorted(d.items(), key=lambda x: x[1], reverse=True):
    if count > 1000:
        print(city, count)
# Out:
# Philadelphia 14569
# Tucson 9250
# Tampa 9050
# Indianapolis 7540
# Nashville 6971

# %%
businesses.head(3)
# Out:
#            city  review_count                name             business_id  \
# 0        Tucson            22              Target  tUFrWirKiKi_TAnsVWINQQ
# 1  Philadelphia            80  St Honore Pastries  MTSW4McQd7CbVtyjqoe9mw
# 2     Nashville            10      Sonic Drive-In  bBDDEgkFA1Otx9Lfe7BZUQ
#
#     longitude state  stars               address   latitude     metroarea  \
# 0 -110.880452    AZ    3.5  5255 E Broadway Blvd  32.223236        Tucson
# 1  -75.155564    PA    4.0           935 Race St  39.955505  Philadelphia
# 2  -86.768170    TN    1.5   2312 Dickerson Pike  36.208102     Nashville
#
#                                           categories
# 0  Department Stores, Shopping, Fashion, Home & G...
# 1  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 2  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...

# %% [markdown]
# ## Dataset for Each Metro

# %%
# These cities contain almost all reviews in the dataset (removing outlier entries)
metros = [city for city, count in sorted(d.items(), key=lambda x: x[1], reverse=True)]
print(metros)

# Initialize empty dataframe for each city
metro_reviews = {metro:pd.DataFrame() for metro in metros}

# Dictionary of city IDs to set of business IDs in that city
metro_businesses = {metro:set(businesses[businesses['metroarea'] == metro]['business_id'].tolist()) for metro in metros}
print(metro_businesses)

num_total_reviews = 0

with pd.read_csv("yelp_academic_dataset_review.csv", chunksize=100000) as reader:
    for count, chunk in enumerate(reader):
        #####
        chunk['datetime'] = pd.to_datetime(chunk['date'])
        chunk = chunk[chunk['datetime'] >= pd.Timestamp('2010-01-01')]
        chunk = chunk[chunk['datetime'] < pd.Timestamp('2020-01-01')]
        #print(chunk.head(5))
        #####
        num_total_reviews += len(chunk)
        for metro in metros:
            vals = chunk[chunk.business_id.isin(metro_businesses[metro])]
            metro_reviews[metro] = pd.concat([metro_reviews[metro], vals], axis=0)
        if count % 10 == 0:
            print("Chunk #", count)
        #break
    print("End: Chunk #", count)

print(num_total_reviews)
    
for metro in metros:
    #metro_reviews[metro].to_csv("small_reviews/yelp_academic_dataset_reviews_" + metro + ".csv")
    metro_reviews[metro].to_csv("small_reviews_urbcomp/yelp_academic_dataset_reviews_" + metro + ".csv")
    print(metro_reviews[metro].head(5))
    # business_review_count = metro_reviews[metro].groupby(
    #     'business_id')['review_count'].agg(['median', 'sum'])
# Out:
# ['Philadelphia', 'Tucson', 'Tampa', 'Indianapolis', 'Nashville']
'-3m_nXlyvdKAVNNmVirpGQ', 'K83AQ_2U1Fuf_TIF-fRRXg', 'Ryt1Fhgz7sixMQSJiLyP_g', 'S5VH9dR3nCgNO5C0M_HttA', 'JvnbsGub9FbXVJftM2Zn7A', 'NbOWECn3ilz4gWL6dm5P6g', 'vDqnQGBfPUOUichR2KbDTg', 'AXRSeJZfr9pi1wJQ61D4UQ', 'Am5wWa0v13NZRsJ-g9f9cQ', '5Orn19gUeqCgKu5IRYlvpQ', 'LoVVyTKjpuH3H3q8Iyre_g', '2Cmu7E34u1z07TIIECRNsw', 'JAMmjTFdUGBpV24K1riSjQ', 'vaoSpYVAFXLvRfJGK1IF2g', 'Lcco-Yzab4bqjQnhUKg05A', 'RrM_40kC8x3x17uHJngyrg', 'MPQww2b74ASo1CW05BpubA', '_B8Vey_acNLE_uqGfwp49Q', 'WxB8498ejPtHE7wFa89_fA', 'Lst ...
# Chunk # 0
# Chunk # 10
# Chunk # 20
# Chunk # 30
# Chunk # 40
# Chunk # 50
# Chunk # 60
# End: Chunk # 69
# 5643186
#     funny  useful               review_id  \
# 1       0       1  BiTunyQ73aT9WBnpR9DZGw
# 3       0       1  AqPFMleE6RsU23_auESxiA
# 5       2       1  JrIxlS1TzJ-iCu79ul40cQ
# 16      0       0  oyaMhzBSwfGgemSGuZCdwQ
# 19      0       0  Xs8Z8lmKkosqW5mw_sVAoA
#
#                                                  text             business_id  \
# 1   I've taken a lot of spin classes over the year...  7ATYjTIgM3jUlt4UM3IypQ
# 3   Wow!  Yummy, different,  delicious.   Our favo...  kxX2SOes4o-D3ZQBkiMRfA
# 5   I am a long term frequent customer of this est...  04UD14gamNjLY0IDYVhHJg
# 16  Tremendous service (Big shout out to Douglas) ...  YtSqYv1Q_pOltsVPSx54SA
# 19  My absolute favorite cafe in the city. Their b...  eFvzHawVJofxSnD7TgbZtg
#
#     stars                 date                 user_id  cool  \
# 1     5.0  2012-01-03 15:28:18  OyoGAe7OKpv6SyGZT5g77Q     1
# 3     5.0  2015-01-04 00:01:03  _7bHUi9Uuf5__HHc_Q8guQ     1
# 5     1.0  2015-09-23 23:10:31  eUta8W_HdHMXPzLBBZhL1A     1
# 16    5.0  2013-06-24 11:21:25  Dd1jQj7S-BFGqRbApFzCFw     0
# 19    5.0  2014-11-12 15:30:27  IQsF3Rc6IgCzjVV9DE8KXg     0
#
#               datetime
# 1  2012-01-03 15:28:18
# 3  2015-01-04 00:01:03
# 5  2015-09-23 23:10:31
# 16 2013-06-24 11:21:25
# 19 2014-11-12 15:30:27
#      funny  useful               review_id  \
# 2        0       0  saUsX_uimxRlCVr67Z4Jig
# 14       2       0  UBp0zWyH60Hmw6Fsasei7w
# 75       0       0  ymhbOMW63B_vGaRFR3XT0A
# 93       0       0  onlgwy5qGDEzddsrnIvtWg
# 120      1       2  xS4qtB70SM-q7kX7smKlRg
#
#                                                   text  \
# 2    Family diner. Had the buffet. Eclectic assortm...
# 14   The bun makes the Sonoran Dog. It's like a snu...
# 75   I just started going to Sushi Nara this month ...
# 93   Don't know what it is but If my tummy's feelin...
# 120  OMG!!! I can't believe this kind of service ex...
#
#                 business_id  stars                 date  \
# 2    YjUWPpI6HXG530lwP-fb2A    3.0  2014-02-05 20:30:30
# 14   otQS34_MymijPTdNBoBdCw    4.0  2011-10-27 17:12:05
# 75   5Ce3lZksYVkCbrihqylVHQ    5.0  2014-07-25 17:56:26
# 93   W7NxQw8UYFR0HLPrI08tvw    4.0  2012-02-01 14:21:25
# 120  zt2JwrXrou8PyDELJOOA_w    1.0  2014-06-28 19:44:23
#
#                     user_id  cool            datetime
# 2    8g_iMtfSiwikVnbP2etR0A     0 2014-02-05 20:30:30
# 14   4Uh27DgGzsp6PqrH913giQ     0 2011-10-27 17:12:05
# 75   yZdAhQ_KmKuCZmbBy9YDQg     0 2014-07-25 17:56:26
# 93   pYXeL0RCqus2IfhthYCOyA     0 2012-02-01 14:21:25
# 120  _Y7-za074Q1sx6t6EucTwA     0 2014-06-28 19:44:23
#     funny  useful               review_id  \
# 10      0       2  rGQRf8UafX7OTlMNN19I8A
# 15      0       0  OAhBYw8IQ6wlfw1owXWRWw
# 18      0       2  u2vzZaOqJ2feRshaaF1doQ
# 74      0       1  EZarjNNbO_2yH1Xbizog9g
# 84      1       0  meGaFP7yxQdjyABrYDVeoQ
#
#                                                  text             business_id  \
# 10  My experience with Shalimar was nothing but wo...  uMvVYRgGNXf5boolA9HXTw
# 15  Great place for breakfast! I had the waffle, w...  BVndHaLihEYbr76Z0CMEGw
# 18  I go to blow bar to get my brows done by natal...  CLEWowfkj-wKYJlQDqT1aw
# 74  First time here and they did a great job, very...  pR8u8hXf1vvzoAGOoKHQqQ
# 84  Skip this train wreck if you are looking for d...  cg4JFJcCxRTTMmcg9O9KtA
#
#     stars                 date                 user_id  cool  \
# 10    5.0  2015-06-21 14:48:06  1WHRWwQmZOZDAhp2Qyny4g     0
# 15    5.0  2014-10-11 16:22:06  1C2lxzUo1Hyye4RFIXly3g     0
# 18    5.0  2016-03-07 00:02:18  NDZvyYHTUWWu-kqgQzzDGQ     1
# 74    5.0  2016-08-25 17:17:46  R_W9WlKiA56VzVbRzTULQQ     0
# 84    1.0  2018-02-11 03:11:20  _jaJDV-qTBafatbObmtzpA     0
#
#               datetime
# 10 2015-06-21 14:48:06
# 15 2014-10-11 16:22:06
# 18 2016-03-07 00:02:18
# 74 2016-08-25 17:17:46
# 84 2018-02-11 03:11:20
#      funny  useful               review_id  \
# 11       0       0  l3Wk_mvAog6XANIuGQ9C7Q
# 24       0       1  lUUhg8ltDsUZ9h0xnwY4Dg
# 55       0       0  EoN2xyKvTTn9B-z1grhYxw
# 65       0       0  Ti6y48ya3syOndm7teSjcg
# 127      0       2  940tqxFO4Pwg_KMg4Y4Z5g
#
#                                                   text  \
# 11   Locals recommended Milktooth, and it's an amaz...
# 24   I was really between 3 and 4 stars for this on...
# 55   I love the Brewpub for their variety of dishes...
# 65   I stopped here because it was by the hotel I w...
# 127  Milktooth is the place to go if you want a goo...
#
#                 business_id  stars                 date  \
# 11   EQ-TZ2eeD_E0BHuvoaeG5Q    4.0  2015-08-19 14:31:45
# 24   cPepkJeRMtHapc_b2Oe_dw    4.0  2018-07-17 03:30:07
# 55   oJ4ik-4PZe6gexxW-tSmsw    4.0  2016-10-26 15:29:56
# 65   O8BBn8lry8lLoIFmChceGg    5.0  2014-08-10 23:56:17
# 127  EQ-TZ2eeD_E0BHuvoaeG5Q    5.0  2018-01-10 01:48:58
#
#                     user_id  cool            datetime
# 11   ZbqSHbgCjzVAqaa7NKWn5A     0 2015-08-19 14:31:45
# 24   RreNy--tOmXMl1en0wiBOg     1 2018-07-17 03:30:07
# 55   DBYhpb5hrAYgQjQaMhNYyQ     0 2016-10-26 15:29:56
# 65   NGTzj_44YDnPDmsD45HWeg     0 2014-08-10 23:56:17
# 127  O6wkgoJqU7KMjleSlCDGaA     1 2018-01-10 01:48:58
#     funny  useful               review_id  \
# 29      0       0  elqRpX9T3YwL07uLNtN3Bg
# 34      0       0  p198qZsKOMCUhgdtRWsOKQ
# 39      0       0  E9AB7V4z8xrt2uPF7T55FQ
# 43      0       0  qGQvUHmC02PAZW3H1WTIfw
# 63      0       1  67cGcRrS0jTvB8p7rpaPew
#
#                                                  text             business_id  \
# 29  I at least have to give this restaurant two st...  ltBBYdNzkeKdCNPDAsxwAA
# 34  After my ROTD  yesterday of a different Sweet ...  8QnuWGVNBhzyYXGSeRdi4g
# 39  Amazing biscuits and (fill in the blank). Grea...  Zx7n8mdt8OzLRXVzolXNhQ
# 43  Stopped by after a Sunday morning walk in the ...  eaJCpC6IhYphj7bwCDHTwQ
# 63  Honestly the food doesn't knock my socks off b...  oQ5CPRt0R3AzFvcjNOqB1w
#
#     stars                 date                 user_id  cool  \
# 29    2.0  2015-02-02 04:29:13  -sryo4gDYxbZ1T5Bz4l5Bw     0
# 34    4.0  2013-10-24 19:24:33  3MpDvy5gEdsbZh9-p92dHg     0
# 39    5.0  2018-04-27 23:03:21  iYY5Ii1LGpZCpXFkHlMefw     0
# 43    5.0  2015-08-30 13:41:47  RRTQpg8hutdimzAYuP_Hbw     0
# 63    3.0  2016-01-17 13:26:19  8YSxVaD203mE_9FR4nCEVA     0
#
#               datetime
# 29 2015-02-02 04:29:13
# 34 2013-10-24 19:24:33
# 39 2018-04-27 23:03:21
# 43 2015-08-30 13:41:47
# 63 2016-01-17 13:26:19

# %%
import plotly.subplots as sp
import plotly.express as px

fig = sp.make_subplots(rows=1, cols=len(metros), subplot_titles=[
                       f"{metro}" for metro in metros], shared_yaxes=True)

for i, metro in enumerate(metros):
    df = metro_reviews[metro]
    review_counts = df.groupby('business_id')['review_id'].count()
    fig.add_box(x=review_counts, row=1, col=i+1)
    fig.update_xaxes(title_text='Review Count', row=1, col=i+1)
    fig.update_yaxes(title_text='Metro', row=1, col=i+1)

fig.show()

# %% [markdown]
# ## Checking Results

# %%
print(metros)
# Out:
# ['Philadelphia', 'Tucson', 'Tampa', 'Indianapolis', 'Nashville']

# %%
lengths = [len(metro_reviews[metro]) for metro in metros]
print(lengths)
print(sum(lengths))
print(num_total_reviews)
# Out:
# [813634, 321269, 359167, 289986, 361162]
# 2145218
# 5643186
